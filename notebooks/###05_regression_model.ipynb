# %%
#############################################
# Notebook 05 – Hedonisches Regressionsmodell
# Projekt: Preisbewertung NL
#############################################

import sys
# !{sys.executable} -m pip install statsmodels

import statsmodels.api as sm
import pandas as pd
# Out:
# Requirement already satisfied: statsmodels in c:\users\sk\appdata\local\python\pythoncore-3.14-64\lib\site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\sk\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from statsmodels) (2.4.1)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\sk\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from statsmodels) (1.17.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\sk\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\sk\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\sk\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sk\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sk\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sk\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\sk\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\sk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\sk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~upyterlab (C:\Users\sk\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\sk\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
# csv-Dateien laden

df_model = pd.read_csv('../data_clean/df_model_prepared.csv')
X = pd.read_csv('../data_clean/X_features.csv')
y = pd.read_csv('../data_clean/y_target.csv')

# %%
# Konstantenvektor hinzufügen

X_ols = sm.add_constant(X)

# %%
# Alle bool-Spalten in int umwandeln

bool_cols = X_ols.select_dtypes(include=['bool']).columns
X_ols[bool_cols] = X_ols[bool_cols].astype(int)

# %%
# OLS‑Modell schätzen
model = sm.OLS(y, X_ols).fit()

# %%
# Ergebnisse anzeigen

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        log_price_total   R-squared:                       0.930
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                     881.8
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):               0.00
# Time:                        12:23:15   Log-Likelihood:                 2456.3
# No. Observations:                1690   AIC:                            -4861.
# Df Residuals:                    1664   BIC:                            -4719.
# Df Model:                          25
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      13.0464      0.466     28.010      0.000      12.133      13.960
# income_mean                -0.0165      0.003     -5.585      0.000      -0.022      -0.011
# woz_mean                    0.2086      0.003     61.381      0.000       0.202       0.215
# log_density                -0.0071      0.003     -2.565      0.010      -0.013      -0.002
# migration_per_1000         -0.0045      0.002     -2.566      0.010      -0.008      -0.001
# employment_rate            -0.0057      0.004     -1.478      0.140      -0.013       0.002
# labor_participation_net     0.0090      0.003      3.549      0.000       0.004       0.014
# longitude                  -0.0327      0.005     -6.594      0.000      -0.042      -0.023
# latitude                    0.0023      0.009      0.263      0.793      -0.015       0.020
# is_randstad                -0.0756      0.010     -7.378      0.000      -0.096      -0.055
# province_Flevoland         -0.0195      0.009     -2.082      0.037      -0.038      -0.001
# province_Fryslân           -0.0798      0.011     -7.255      0.000      -0.101      -0.058
# province_Gelderland        -0.0264      0.012     -2.235      0.026      -0.050      -0.003
# province_Groningen         -0.1145      0.012     -9.606      0.000      -0.138      -0.091
# province_Limburg           -0.0804      0.018     -4.541      0.000      -0.115      -0.046
# province_Noord-Brabant     -0.0536      0.016     -3.307      0.001      -0.085      -0.022
# province_Noord-Holland     -0.0152      0.005     -2.790      0.005      -0.026      -0.004
# province_Overijssel        -0.0615      0.010     -5.877      0.000      -0.082      -0.041
# province_Utrecht           -0.0229      0.006     -3.839      0.000      -0.035      -0.011
# province_Zeeland           -0.1255      0.021     -5.882      0.000      -0.167      -0.084
# province_Zuid-Holland      -0.0180      0.007     -2.532      0.011      -0.032      -0.004
# ratio_price_model           0.0488      0.015      3.151      0.002       0.018       0.079
# ratio_stock                -0.0613      0.016     -3.871      0.000      -0.092      -0.030
# woningvoorraad_total       -0.0837      0.039     -2.166      0.030      -0.159      -0.008
# pipeline_total             -0.0026      0.006     -0.425      0.671      -0.015       0.009
# new_build_stock_tot         0.0024      0.005      0.454      0.650      -0.008       0.013
# households                  0.0828      0.041      2.027      0.043       0.003       0.163
# ==============================================================================
# Omnibus:                       66.710   Durbin-Watson:                   0.427
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              136.638
# Skew:                          -0.258   Prob(JB):                     2.13e-30
# Kurtosis:                       4.294   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.62e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Differenzen zwischen den tatsächlichen Werten und den vorhergesagten Werten prüfen

import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(model.resid, kde=True)
plt.title("Verteilung der Residuen")
plt.show()
