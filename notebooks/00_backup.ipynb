# %%
import shutil

shutil.copy("../data_clean/df_model_prepared.csv", "../data_clean/df_model_prepared_BACKUP.csv")
shutil.copy("../data_clean/df_geo.csv", "../data_clean/df_geo_BACKUP.csv")

print("Backups erstellt.")
# Out:
# Backups erstellt.
